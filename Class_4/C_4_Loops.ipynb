# %% [markdown]
# <a href="https://colab.research.google.com/github/mromankhan/Python/blob/main/Class_4/C_4_Loops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Loops
#
# ### There are two type of Loops
#
#
# 1.   For Loop
# 2.   While Loop

# %%
# 1) For loop

# fruits = ["apple", "banana", "cherry", "mango"]

# Simple Loop

# for fruit in fruits:
#   print(fruit)

# for word in "hello loops":
#   print(word)


# Loop with break Keyword

# for f in fruits:
#   print(f)
#   if f == "banana":
#     break

# for f in fruits:
#   print(f)
#   if f == "cherry":
#     break
#     print(f)


# Loop with continue Keyword

# for f in fruits:
#   if f == "banana":
#     continue
#   print(f)


# range() Function

# for i in range(5):
#   print(i)

# for i in range(2, 5):
#   print(i)

# for i in range(5, 20, 5):
#   print(i)


# Loop with else Keyword

# for i in range(5):
#   print(i)
# else:
#   print("finally fineshed")

# for i in range(5):
#   if i == 3: break
#   print(i)
# else:
#   print("finally finished")


# Nested Loop

# adj = ["red", "big", "tasty"]
# fruits = ["apple", "banana", "cherry"]

# for c in adj:
#   for f in fruits:
#     print(c, f)


# pass keyword

# for i in [0, 1, 2]:
#   pass

# %%
# 2) While loop

# Simple Loop

i = 0
# while i < 5:
#   print(i)
#   i += 1


# while i < 5:
#   print(i)
#   if i == 3:
#     break
#   i += 1


# while i < 5:
#   i += 1
#   if i == 3:
#     continue
#   print(i)


# while i < 5:
#   print(i)
#   i += 1
# else:
#   print("i is no longer less than 6")
# Out:
# 0
# 1
# 2
# 3
# 4
# i is no longer less than 6
