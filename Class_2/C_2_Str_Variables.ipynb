# %% [markdown]
# <a href="https://colab.research.google.com/github/mromankhan/Python/blob/main/Class_2/C_2_Str_Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Strings:
#
#
# 1.   Normal String
# 2.   Doc String or Multiline String
# 3.   f String

# %%
# Strings

# Normal String
print("1.This is normal String")

# Doc String or Multiline String
print("""2.This is a Doc String
or Multiline String""")

# f string
f_string = "f"
print(f"3.This is a {f_string} String")
# Out:
# 1.This is normal String
# 2.This is a Doc String
# or Multiline String
# 3.This is a f String

# %% [markdown]
# # Variables

# %%
name = "Roman"
roll_num = 12345
roll_num_2 = 12345.70


print(f"Student name is {name} and roll number is {roll_num}")
print(f"""student name is {name}
& student rool number is {roll_num}""")

# print(type(name))
# print(type(roll_num))
# print(type(roll_num_2))
# Out:
# Student name is Roman and roll number is 12345
# student name is Roman
# & student rool number is 12345
